# %% [markdown]
# # Machine Learning Project
# ## Прогнозирование оттока клиентов телекоммуникационной компании
#
# <br><br>
# **Описание работы:**
# &nbsp;&nbsp;&nbsp;&nbsp;
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; Любой бизнес хочет максимизировать количество клиентов. Для достижения этой цели важно не только пытаться привлечь новых, но и удерживать уже существующих. Удержать клиента обойдется компании дешевле, чем привлечь нового. Кроме того, новый клиент может оказаться слабо заинтересованным в услугах бизнеса и с ним будет сложно работать, тогда как о старых клиентах уже есть необходимые данные по взаимодействию с сервисом.
#  <br>
#
# &nbsp;&nbsp;&nbsp;&nbsp; Соответственно, прогнозируя отток, мы можем вовремя среагировать и попытаться удержать клиента, который хочет уйти. Опираясь на данные об услугах, которыми пользуется клиент, мы можем сделать ему специальное предложение, пытаясь изменить его решение об уходе от оператора. Благодаря этому задача удержания будет легче в реализации, чем задача привлечения новых пользователей, о которых мы еще ничего не знаем.<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp; Вам предоставлен набор данных от телекоммуникационной компании. В данных содержится информация о почти шести тысячах пользователей, их демографических характеристиках, услугах, которыми они пользуются, длительности пользования услугами оператора, методе оплаты, размере оплаты.
# <br>
#
# &nbsp;&nbsp;&nbsp;&nbsp; Cтоит задача проанализировать данные и спрогнозировать отток пользователей (выявить людей, которые продлят контракт и которые не продлят). Работа должна включать в себя следующие обязательные пункты:
# 1. Описание данных *(с расчетом базовых статистик)*,
# 2. Исследование зависимостей и формулирование гипотез,
# 3. Построение моделей для прогнозирования оттока *(с обоснованием выбора той или иной модели)* на основе проверенных гипотез и выявленных взаимосвязей,
# 4. Сравнение качества полученных моделей.
# <br><br>
# _________
#
# [Codebook](#Codebook) <br>
# 1. [Описание данных](#1.-Описание-данных)<br>
# 2. [Исследование зависимостей и формулирование гипотез](#2.-Исследование-зависимостей-и-формулирование-гипотез)<br>
# 3. [Построение моделей для прогнозирования оттока](#3.-Построение-моделей-для-прогнозирования-оттока)<br>
#     3.1 [Обучение алгоритмов на всех признаках с базовыми гиперпараметрами](#3.1-Обучение-алгоритмов-на-всех-признаках-с-базовыми-гиперпараметрами)<br>
#     3.2 [Обучение алгоритмов с базовыми гиперпараметрами на нормализованных данных (PCA)](#3.2-Обучение-алгоритмов-с-базовыми-гиперпараметрами-на-нормализованных-данных-(PCA))<br>
#     3.3 [Обучение алгоритмов с базовыми гиперпараметрами на отобранных признаках](#3.3-Обучение-алгоритмов-с-базовыми-гиперпараметрами-на-отобранных-признаках)<br>
#     3.4 [Обучение отобранных алгоритмов на кросс-валидации, настройка гиперпараметров](#3.4-Обучение-отобранных-алгоритмов-на-кросс-валидации,-настройка-гиперпараметров)<br>
# 4. [Сравнение качества моделей](#4.-Сравнение-качества-моделей) <br>

# %% [markdown]
# ## Codebook
# <br>
#
# `telecom_users.csv` содержит следующие значения:<br><br>
#
# &nbsp;&nbsp;&nbsp;&nbsp; `customerID` – id клиента<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `gender` – пол клиента (male/female)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `SeniorCitizen` – яляется ли клиент пенсионером (1, 0)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Partner` – состоит ли клиент в браке (Yes, No)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Dependents` – есть ли у клиента иждивенцы (Yes, No)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `tenure` – сколько месяцев человек являлся клиентом компании<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `PhoneService` – подключена ли услуга телефонной связи (Yes, No)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `MultipleLines` – подключены ли несколько телефонных линий (Yes, No, No phone service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `InternetService` – интернет-провайдер клиента (DSL, Fiber optic, No)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `OnlineSecurity` – подключена ли услуга онлайн-безопасности (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `OnlineBackup` – подключена ли услуга online backup (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `DeviceProtection` – есть ли у клиента страховка оборудования (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `TechSupport` – подключена ли услуга технической поддержки (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `StreamingTV` – подключена ли услуга стримингового телевидения (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `StreamingMovies` – подключена ли услуга стримингового кинотеатра (Yes, No, No internet service)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Contract` – тип контракта клиента (Month-to-month, One year, Two year)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `PaperlessBilling` – пользуется ли клиент безбумажным биллингом (Yes, No)<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `PaymentMethod` – метод оплаты (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `MonthlyCharges` – месячный размер оплаты на настоящий момент<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `TotalCharges` – общая сумма, которую клиент заплатил за услуги за все время<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Churn` – произошел ли отток (Yes or No)<br>

# %% [markdown]
# # 1. Описание данных

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
from textwrap import wrap

sns.set_palette("inferno")
sns.set_style('whitegrid')

plt.rcParams["font.size"] = "13"

# %%
# Чтение данных из файла и удаление некорректных данных
data = pd.read_csv('telecom_users.csv')
data = data.drop('Unnamed: 0', axis=1)
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7010-BRBUU    Male              0     Yes        Yes      72          Yes
# 1  9688-YGXVR  Female              0      No         No      44          Yes
# 2  9286-DOJGF  Female              1     Yes         No      38          Yes
# 3  6994-KERXL    Male              0      No         No       4          Yes
# 4  2181-UAESM    Male              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0           Yes              No  No internet service  ...
# 1            No     Fiber optic                   No  ...
# 2           Yes     Fiber optic                   No  ...
# 3            No             DSL                   No  ...
# 4            No             DSL                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
# Декодировка категориального признака
data.SeniorCitizen.replace([0, 1], ['No', 'Yes'], inplace=True)
data.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7010-BRBUU    Male            No     Yes        Yes      72          Yes
# 1  9688-YGXVR  Female            No      No         No      44          Yes
# 2  9286-DOJGF  Female           Yes     Yes         No      38          Yes
# 3  6994-KERXL    Male            No      No         No       4          Yes
# 4  2181-UAESM    Male            No      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0           Yes              No  No internet service  ...
# 1            No     Fiber optic                   No  ...
# 2           Yes     Fiber optic                   No  ...
# 3            No             DSL                   No  ...
# 4            No             DSL                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
# Проверка пропущенных значений
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5986 non-null   object
#  1   gender            5986 non-null   object
#  2   SeniorCitizen     5986 non-null   object
#  3   Partner           5986 non-null   object
#  4   Dependents        5986 non-null   object
#  5   tenure            5986 non-null   int64
#  6   PhoneService      5986 non-null   object
#  7   MultipleLines     5986 non-null   object
#  8   InternetService   5986 non-null   object
#  9   OnlineSecurity    5986 non-null   object
#  10  OnlineBackup      5986 non-null   object
#  11  DeviceProtection  5986 non-null   object
#  12  TechSupport       5986 non-null   object
#  13  StreamingTV       5986 non-null   object
#  14  StreamingMovies   5986 non-null   object
#  15  Contract          5986 non-null   object
# ...

# %%
# Приведение данных числового признака к соответствующему типу
data.TotalCharges = pd.to_numeric(data.TotalCharges, errors='coerce')
data.TotalCharges.fillna(data.tenure * data.MonthlyCharges, inplace=True)

# %%
# Исследование базовых статистик числовых признаков
describe_numerical = data.describe()
features_num = describe_numerical.columns
describe_numerical
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  5986.000000     5986.000000   5986.000000
# mean     32.468760       64.802213   2294.221559
# std      24.516391       30.114702   2274.164124
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.650000    401.587500
# 50%      29.000000       70.400000   1408.575000
# 75%      56.000000       89.900000   3841.500000
# max      72.000000      118.750000   8684.800000

# %%
# Исследование базовых статистик категориальных признаков
describe_categorical = data.describe(include=np.object)
features_cat = describe_categorical.columns.drop(['customerID', 'Churn'])
describe_categorical
# Out:
#         customerID gender SeniorCitizen Partner Dependents PhoneService  \
# count         5986   5986          5986    5986       5986         5986
# unique        5986      2             2       2          2            2
# top     7225-CBZPL   Male            No      No         No          Yes
# freq             1   3050          5020    3082       4195         5396
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count           5986            5986           5986         5986
# unique             3               3              3            3
# top               No     Fiber optic             No           No
# freq            2848            2627           2982         2605
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              5986        5986        5986            5986
# unique                3           3           3               3
# top                  No          No          No              No
# ...

# %%
# Удаление столбца, не влияющего на целевой признак
data.drop('customerID', axis=1, inplace=True)

# %%
# Визуализация числовых признаков
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
fig.suptitle('Distributions of numerical features', y=1, fontsize=18)

for i, feature in enumerate(features_num):
    sns.histplot(data[feature], ax=ax[i], alpha=0.9, bins=100)
    ax[i].set_title(feature)
    
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['top'].set_visible(False)
    
ax[0].set_xlabel('Months of use')
ax[1].set_xlabel('Monthly charges, $')
ax[2].set_xlabel('Total charges, $')
    
plt.tight_layout(pad=1.03)
plt.show()

# %%
# Визуализация категориальных признаков
fig, ax = plt.subplots(4, 4, figsize=(20, 15))
fig.suptitle('Distributions of categorical features', y=1, fontsize=22)

for ax, feature in zip(ax.ravel(), features_cat):
    sns.barplot(x=data[feature].value_counts().index, 
                y=data[feature].value_counts().values, 
                ax=ax, alpha=0.9)
    
    ax.set_title(feature, fontdict={'fontsize' : 16})
    ax.set_yticks(range(0, data[feature].value_counts().max() + 500, 500))
    
    # Отключение рамок
    for _, spine in ax.spines.items():
        spine.set_visible(False)
    ax.spines['left'].set_visible(True)
    
# Редактирование лейблов на последнем графике для корректного отображения
last_labels = ['Credit\ncard\n(automatic)', 'Bank\ntransfer\n(automatic)', 'Electronic\ncheck', 'Mailed\ncheck']
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(last_labels)
    

    
plt.tight_layout(pad=1.03)
plt.show()

# %%
# Визуализация целевого признака
plot = sns.barplot(x=data['Churn'].value_counts().index, 
                   y=data['Churn'].value_counts().values, 
                   palette=['#f6604d', '#3a295f'], 
                   alpha=0.9)

plt.title('Target = Churn')
plt.yticks(range(0, data['Churn'].value_counts().max() + 500, 500))

# Отображение процента оставшихся и ушедших клиентов
for n, i in enumerate(plot.patches):
    plt.text(x=i.get_x() + 0.3,
             y=i.get_height() / 2, 
             s=str(np.around(data['Churn'].value_counts().values / 
                             data['Churn'].count() * 100, 1)[n]) + '%',
             color='white',
             fontsize=14)
    
plt.box(None)
plt.show()

# %% [markdown]
# #### Выводы:
# * В данных нет повторяющейся информации о клиентах, а также пропущенных данных (за исключением признакак *TotalCharges*, который можно заполнить с помощью признаков *tenure и MonthlyCharges*).
# * Среди клиентов практически одинаковое количество мужчин и женщин, а также количество людей, состоящих и не состоящих в браке.
# * Только 1/6 от всех клиентов — пенсионеры.
# * У 1/3 клиентов есть иждевенцы.
# * 90% клиентов имеют подключенную связь, при этом половина клиентов пользуется несколькими телефонными линиями.
# * Большинство клиентов не пользуются дополнительными услугами.
# * Медианное время пользования услугами компании составляет примерно **32 месяца**. Максимальное - **72 месяца**.
# * Медианный ежемесячный чек — **64.8\$**, при этом у многих клиентов месячный платеж составляет около **20\$**.
# * Больше половины клиентов имеют тип контракта *Month-to-month*.
# * Большая часть клиентов использует *безбумажный биллинг*.
# * *Credit card (automatic)* является приоритетным способом оплаты.
# * Процент оттока клиентов составляет **26.5%**

# %% [markdown]
# # 2. Исследование зависимостей и формулирование гипотез

# %%
# Визуализация целевого признака в разрезе каждого из числовых признаков
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Distribution of the "Churn" feature within numerical features', fontsize=18)

for feature, ax in zip(features_num, axes.ravel()[:3]):
    sns.kdeplot(data.query('Churn == "Yes"')[feature], 
                color = '#3a295f', 
                shade = True, 
                alpha = 0.6, 
                label = 'Client left', 
                ax=ax)
    
    sns.kdeplot(data.query('Churn == "No"')[feature], 
                color = '#f6604d', 
                shade = True, 
                alpha = 0.7, 
                label = 'Client stayed',
                ax=ax)
    
    ax.set_ylabel(None)
    ax.set_yticks([])
    ax.set_title(feature)
    
    # Отключение рамок
    for _, spine in ax.spines.items():
        spine.set_visible(False)
    ax.spines['bottom'].set_visible(True)
    
axes[0].set_xlabel('Months of use')
axes[1].set_xlabel('Monthly charges, $')
axes[2].set_xlabel('Total charges, $')

plt.legend()
    
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Comparison of numerical features in the context of the target feature', fontsize=18)

for feature, ax in zip(features_num, axes.ravel()):
    sns.boxplot(x='Churn', y=feature, data=data, palette=['#f6604d', '#3a295f'], ax=ax)
    
plt.tight_layout(pad=1.03)
plt.show()

# %% [markdown]
# * В среднем, срок пользования услугами компании среди ушедших клиентов значительно ниже. Чем меньше срок, тем чаще уходят клиенты. Возможно, изначально компания предлагает недостаточно выгодные условия.
# * Также, среди ушедших клиентов ежемесячный платеж выше. Предположительно, большинство этих клиентов посчитало, что переплачивает за услуги.

# %%
# Визуализация целевого признака в разрезе каждого из категориальных признаков
fig, axes = plt.subplots(4, 4, figsize=(20, 15))
fig.suptitle('Distribution of the "Churn" feature within categorical features', y=1, fontsize=22)

for ax, feature in zip(axes.ravel(), features_cat):
    # Client left (Churn —'Yes')
    sns.barplot(x=data[feature].value_counts().index, 
                y=data[feature].value_counts().values, 
                label='Yes', 
                color = '#3a295f',
                alpha=0.9,
                ax=ax)
    
    # Client stayed (Churn —'No')
    sns.barplot(x=data[feature].value_counts().index, 
                y=data[data['Churn'] == 'No'][feature].value_counts().values, 
                label='No', 
                color = '#f6604d',
                alpha=1,
                ax=ax)
    
    ax.set_title(feature, fontdict={'fontsize' : 18})
    ax.set_yticks(range(0, data[feature].value_counts().max() + 500, 500))
    ax.set_ylabel(None)
    ax.legend(title='Churn')
    
    # Отображение процента оттока в рамках каждой категории признака
    for n, i in zip(range(0, round(len(ax.patches) / 2)), ax.patches):
        ax.text(x=i.get_x() + 0.25,
                 y=100, 
                 s=str(np.around(
                     data[data['Churn'] == 'Yes'][feature].value_counts().values / 
                     data[feature].value_counts().values * 100, 1)[n]) + '%',
                 color='white',
                 fontsize=16)
    # Отключение рамок
    for _, spine in ax.spines.items():
        spine.set_visible(False)
    ax.spines['left'].set_visible(True)
    
# Редактирование лейблов на последнем графике для корректного отображения
last_labels = ['Credit\ncard\n(automatic)', 'Bank\ntransfer\n(automatic)', 'Electronic\ncheck', 'Mailed\ncheck']
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(last_labels)

    
plt.tight_layout(pad=1.03)
plt.show()

# %% [markdown]
# * Отток почти не зависит от признаков **gender, PhoneService, MultipleLines, StreamingTV и StreamingMovies**.
# * Клиенты, не имеющие иждевенцев, уходят *примерно в 2 раза чаще*.
# * Клиенты, не пользующиеся услугами безопасности (**OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport**) уходят *в 2-2.5 раза чаще*.
# * Клиенты, которые не пользуются интернетом, также *реже уходят*. При этом среди пользующихся интернетом клиентов *в 2 раза чаще* уходят клиенты с подключением типа **Fiber Optic**.
# * Клиенты с долгосрочными контрактами *значительно реже* уходят.
# * Те, кто пользуются безбумажным биллингом, а также кредитной картой для оплаты уходят *примерно в 2 раза чаще*.

# %%
# Создание датафрейма с закодированными признаками
data_2 = data.copy()
data_2[features_cat] = data_2[features_cat].apply(lambda x: x.astype('category').cat.codes)
data_2['Churn'] = data_2['Churn'].astype('category').cat.codes

# %%
data_2.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           1      72             1
# 1       0              0        0           0      44             1
# 2       0              1        1           0      38             1
# 3       1              0        0           0       4             1
# 4       1              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              2                2               1             1
# 1              0                1               0             2
# 2              2                1               0             0
# 3              0                0               0             0
# 4              0                0               2             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 1            1            1                1         2
# ...

# %%
# Исследование корреляции признаков по тепловой карте
plt.figure(figsize=(20,15))
plt.title('Feature correlation matrix', y=1, size=20)
sns.heatmap(data_2.corr(), linewidths=0.1, annot=True, cmap='inferno')
plt.show()

# %%
# Корреляция фичей с целевым признаком
correlation = pd.DataFrame(data_2.corr()['Churn'].sort_values(ascending=False)).drop('Churn')
correlation.style.background_gradient(cmap = 'inferno', vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_b4431_row0_col0{
#             background-color:  #db503b;
#             color:  #000000;
#         }#T_b4431_row1_col0{
#             background-color:  #da4e3c;
#             color:  #000000;
#         }#T_b4431_row2_col0{
#             background-color:  #d54a41;
#             color:  #f1f1f1;
#         }#T_b4431_row3_col0{
#             background-color:  #ce4347;
#             color:  #f1f1f1;
#         }#T_b4431_row4_col0{
#             background-color:  #c13a50;
#             color:  #f1f1f1;
#         }#T_b4431_row5_col0{
#             background-color:  #bd3853;
#             color:  #f1f1f1;
#         }#T_b4431_row6_col0{
#             background-color:  #b93556;
#             color:  #f1f1f1;
#         }#T_b4431_row7_col0{
#             background-color:  #b43359;
#             color:  #f1f1f1;
#         }#T_b4431_row8_col0{
#             background-color:  #b3325a;
#             color:  #f1f1f1;
#         }#T_b4431_row9_col0{
# ...

# %% [markdown]
# С целевой переменной *Churn* имеется слабая корреляционная связь у признаков: **PaperlessBilling, MonthlyCharges, TotalCharges, DeviceProtection, OnlineBackup, TechSupport, OnlineSecurity, Tenure, Contract**.

# %% [markdown]
# # 3. Построение моделей для прогнозирования оттока

# %%
# Импорт библиотек, необходимых для построения и оценки моделей
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# from sklearn.manifold import TSNE

from sklearn.model_selection import (train_test_split, GridSearchCV, StratifiedKFold)
    
from sklearn.metrics import (confusion_matrix,
                             roc_auc_score, precision_score, recall_score, f1_score)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, RandomForestClassifier
from xgboost import XGBClassifier

import time

# %% [markdown]
# ### 3.1 Обучение алгоритмов на всех признаках с базовыми гиперпараметрами

# %%
# Определение фичей и целевого признака, нормализация данных
sc = StandardScaler()

X = data_2.drop('Churn', axis=1)
X[features_num] = sc.fit_transform(X[features_num])
y = data_2['Churn']

# Разбиение данных на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Определение объектов классификаторов с базовыми параметрами

knc = KNeighborsClassifier()
gnb = GaussianNB()
lin_svc = LinearSVC(dual=False, 
                    random_state=42)

dtc = DecisionTreeClassifier(random_state=42)
lgr = LogisticRegression(random_state=42)

rfc = RandomForestClassifier(random_state=42)

sgd = SGDClassifier(random_state=42)

gbc = GradientBoostingClassifier(random_state=42)

abc = AdaBoostClassifier(random_state=42)

xgb = XGBClassifier(use_label_encoder=False,
                    objective = 'binary:logistic', 
                    eval_metric = 'logloss', 
                    random_state=42)

# Определение объекта кросс-валидатора
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# Создание двух списков моделей (имеющих метод predict_proba и не имеющих) для построения предсказаний в цикле
with_predict_proba_models = [knc, gnb, dtc, lgr, rfc, gbc, abc, xgb]
without_predict_proba_models = [lin_svc, sgd]

# %%
# Список всех моделей
models = ['KNeighborsClassifier', 'GaussianNB', 'LinearSVC', 'DecisionTreeClassifier', 'LogisticRegression',
          'RandomForestClassifier', 'SGDClassifier', 'GradientBoostingClassifier', 'AdaBoostClassifier', 'XGBClassifier']

# %%
# Создание датафрейма с метриками, оценивающими работу каждой модели
results = pd.DataFrame(columns = ['roc_auc_score', 'precision_score', 'recall_score', 'f1_score'], index = models)

# %%
print('Training time:\n')

# Обучение моделей, которые имеют метод predict_proba, с базовыми параметрами
for n, model in enumerate(with_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train, y_train)
    
    # Получение предсказаний
    y_prob = current_model.predict_proba(X_test)[:, 1]
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_prob)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")

# Обучение моделей, которые не имеют метода predict_proba, с базовыми параметрами
for n, model in enumerate(without_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train, y_train)
    
    # Получение предсказаний
    y_dec = current_model.decision_function(X_test)
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_dec)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")
    
results.sort_values('roc_auc_score', ascending=False)
# Out:
# Training time:
#
# KNeighborsClassifier: 1.51s
# GaussianNB: 0.08s
# DecisionTreeClassifier: 0.14s
# LogisticRegression: 0.23s
# RandomForestClassifier: 3.1s
# GradientBoostingClassifier: 2.84s
# AdaBoostClassifier: 1.18s
# XGBClassifier: 1.62s
# LinearSVC: 0.14s
# SGDClassifier: 0.16s
#                            roc_auc_score precision_score recall_score  \
# GradientBoostingClassifier       0.83688        0.642077     0.507559
# AdaBoostClassifier              0.836398        0.639687     0.529158
# LogisticRegression              0.833464        0.634021     0.531317
# LinearSVC                        0.82894        0.650407     0.518359
# SGDClassifier                   0.818953        0.601485     0.524838
# RandomForestClassifier          0.816142        0.601108     0.468683
# XGBClassifier                   0.814748         0.59383      0.49892
# GaussianNB                      0.812695        0.508423     0.717063
# ...

# %% [markdown]
# Попробуем нормализовать данные с помощью PCA и еще раз обучить все алгоритмы.

# %% [markdown]
# ### 3.2 Обучение алгоритмов с базовыми гиперпараметрами на нормализованных данных (PCA)

# %%
# Нормализация данных и разбиение их на новые тренировочные и валидационные данные
pca = PCA().fit(X)
X_pca = pca.transform(X)

X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42)

# %%
results_2 = results.copy()

# %%
# Создание словаря для записи confusion_matrix для каждой модели
matrixes = {}
print('Training time:\n')

# Обучение моделей, которые имеют метод predict_proba, с базовыми параметрами
for n, model in enumerate(with_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train_pca, y_train)
    
    # Получение предсказаний
    y_prob = current_model.predict_proba(X_test_pca)[:, 1]
    y_pred = current_model.predict(X_test_pca)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_prob)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results_2.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    matrixes[current_model.__class__.__name__] = confusion_matrix(y_test, y_pred)
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")

# Обучение моделей, которые не имеют метода predict_proba, с базовыми параметрами
for n, model in enumerate(without_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train_pca, y_train)
    
    # Получение предсказаний
    y_dec = current_model.decision_function(X_test_pca)
    y_pred = current_model.predict(X_test_pca)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_dec)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results_2.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    matrixes[current_model.__class__.__name__] = confusion_matrix(y_test, y_pred)
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")
    
results_2.sort_values('f1_score', ascending=False)
# Out:
# Training time:
#
# KNeighborsClassifier: 1.56s
# GaussianNB: 0.05s
# DecisionTreeClassifier: 0.64s
# LogisticRegression: 0.16s
# RandomForestClassifier: 6.45s
# GradientBoostingClassifier: 10.64s
# AdaBoostClassifier: 3.55s
# XGBClassifier: 4.4s
# LinearSVC: 0.12s
# SGDClassifier: 0.2s
#                            roc_auc_score precision_score recall_score  \
# LogisticRegression              0.833467        0.634021     0.531317
# LinearSVC                       0.828927        0.650407     0.518359
# GradientBoostingClassifier      0.830447        0.643243     0.514039
# GaussianNB                      0.803865        0.581776     0.537797
# AdaBoostClassifier              0.823216        0.631148      0.49892
# SGDClassifier                   0.792157        0.558025     0.488121
# KNeighborsClassifier            0.747724         0.51954     0.488121
# RandomForestClassifier          0.798044        0.596439     0.434125
# ...

# %%
# Проверка, насколько изменились значения метрик
results_2 - results
# Out:
#                            roc_auc_score precision_score recall_score  \
# KNeighborsClassifier            0.000143             0.0          0.0
# GaussianNB                     -0.008831        0.073353    -0.179266
# LinearSVC                      -0.000013             0.0          0.0
# DecisionTreeClassifier         -0.027478       -0.036699    -0.043197
# LogisticRegression              0.000003             0.0          0.0
# RandomForestClassifier         -0.018098       -0.004669    -0.034557
# SGDClassifier                  -0.026796        -0.04346    -0.036717
# GradientBoostingClassifier     -0.006432        0.001167     0.006479
# AdaBoostClassifier             -0.013183       -0.008539    -0.030238
# XGBClassifier                  -0.015892       -0.050523    -0.051836
#
#                             f1_score
# KNeighborsClassifier             0.0
# GaussianNB                  -0.03606
# LinearSVC                        0.0
# DecisionTreeClassifier     -0.039775
# ...

# %% [markdown]
# Большинство метрик практически не изменились или ухудшились. Попробуем оставить только те фичи, которые мы выбрали при исследовании зависимостей, и посмотрим, как изменятся значения метрик.

# %% [markdown]
# ### 3.3 Обучение алгоритмов с базовыми гиперпараметрами на отобранных признаках

# %%
# Определение фичей и целевого признака, нормализация данных
X_new = X[['PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 
          'DeviceProtection', 'OnlineBackup', 'TechSupport', 
          'OnlineSecurity', 'tenure', 'Contract']]

# Разбиение данных на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=42)

# %%
results_3 = results.copy()

# %%
print('Training time:\n')

# Обучение моделей, которые имеют метод predict_proba, с базовыми параметрами
for n, model in enumerate(with_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train, y_train)
    
    # Получение предсказаний
    y_prob = current_model.predict_proba(X_test)[:, 1]
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_prob)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results_3.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")

# Обучение моделей, которые не имеют метода predict_proba, с базовыми параметрами
for n, model in enumerate(without_predict_proba_models):
    start = time.time()
    current_model = model.fit(X_train, y_train)
    
    # Получение предсказаний
    y_dec = current_model.decision_function(X_test)
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_dec)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results_3.loc[current_model.__class__.__name__] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{current_model.__class__.__name__}:\033[0m {round(stop - start, 2)}s")
    
results_3.sort_values('roc_auc_score', ascending=False)
# Out:
# Training time:
#
# KNeighborsClassifier: 0.62s
# GaussianNB: 0.05s
# DecisionTreeClassifier: 0.1s
# LogisticRegression: 0.13s
# RandomForestClassifier: 2.34s
# GradientBoostingClassifier: 2.1s
# AdaBoostClassifier: 0.88s
# XGBClassifier: 1.04s
# LinearSVC: 0.08s
# SGDClassifier: 0.11s
#                            roc_auc_score precision_score recall_score  \
# GradientBoostingClassifier      0.835355         0.63172     0.507559
# AdaBoostClassifier              0.832865         0.63172     0.507559
# LogisticRegression              0.828546        0.615385      0.50108
# LinearSVC                       0.824058        0.617486     0.488121
# SGDClassifier                   0.816049        0.590452     0.507559
# RandomForestClassifier           0.80666        0.599469     0.488121
# GaussianNB                      0.806288        0.505155     0.740821
# XGBClassifier                   0.805641        0.577608     0.490281
# ...

# %%
# Проверка, насколько изменились значения метрик
results_3 - results
# Out:
#                            roc_auc_score precision_score recall_score  \
# KNeighborsClassifier            0.032439        0.033091     0.010799
# GaussianNB                     -0.006407       -0.003268     0.023758
# LinearSVC                      -0.004883        -0.03292    -0.030238
# DecisionTreeClassifier          0.000309        0.009338    -0.017279
# LogisticRegression             -0.004918       -0.018636    -0.030238
# RandomForestClassifier         -0.009482       -0.001639     0.019438
# SGDClassifier                  -0.002904       -0.011033    -0.017279
# GradientBoostingClassifier     -0.001525       -0.010356          0.0
# AdaBoostClassifier             -0.003533       -0.007966    -0.021598
# XGBClassifier                  -0.009108       -0.016222    -0.008639
#
#                             f1_score
# KNeighborsClassifier        0.021063
# GaussianNB                  0.005718
# LinearSVC                  -0.031688
# DecisionTreeClassifier     -0.003386
# ...

# %% [markdown]
# Большинство метрик не изменились. Будем использовать данные с отобранными признаками дабы сократить время обучения.

# %% [markdown]
# Выберем лучшие алгоритмы для дальнейшей настройки параметров:
# * Топ 5 алгоритмов из датафрейма *results_3* (**GradientBoostingClassifier, AdaBoostClassifier, LogisticRegression, LinearSVC, SGDClassifier**) незначительно отличаются по значениям метрик.
# * Алгоритм **GaussianNB** имеет явно выделяющееся значение *recall_score*, выберем его тоже, так как в нашем случае как раз более важно значение *recall*.
#
# Итого получили 6 алгоритмов для дальнейшей работы, причем алгоритм **GaussianNB** настроить с помощью *GridSearchCV* не получится.

# %% [markdown]
# ### 3.4 Обучение отобранных алгоритмов на кросс-валидации, настройка гиперпараметров

# %%
# Выбор параметров для дальнейшей настройки алгоритмов
with_predict_proba_params = {
    'LogisticRegression' : {
        'model': lgr,
        'params': {
            'solver': ['lbfgs', 'liblinear'],
            'C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10],
            'max_iter': [100, 200, 500]
        }
    },
    'GradientBoostingClassifier': {
        'model': gbc,
        'params': {
            'learning_rate': np.arange(0.1, 0.6, 0.1)
        }
    },
    'AdaBoostClassifier': {
        'model': abc,
        'params': {
            'n_estimators': range(10, 51, 5),
            'learning_rate': np.arange(0.1, 2, 0.2)
        }
    }
}

without_predict_proba_params = {
    'LinearSVC': {
        'model': lin_svc,
        'params': {
            'C': np.arange(0.1, 1, 0.2),
            'tol': [0.0001, 0.0005, 0.001, 0.005],
            'fit_intercept': [False, True]
        }
    },
    'SGDClassifier': {
        'model': sgd,
        'params': {
            'eta0': np.linspace(0, 0.05, 26),
            'alpha': np.linspace(0.0001, 0.0051, 26)
        }
    },
}

# %%
# Создание датафрейма с метриками, оценивающими работу топовых алгоритмов
results_4 = results_3.copy().drop(['DecisionTreeClassifier', 'XGBClassifier', 
                                   'KNeighborsClassifier', 'RandomForestClassifier'])

# %%
# Обучение моделей, у которых есть метод "predict_proba", на кросс-валидации с подбором гиперпараметров
for model_name, mp in with_predict_proba_params.items():
    start = time.time()
    current_model = GridSearchCV(mp['model'], 
                                 param_grid=mp['params'], 
                                 scoring='roc_auc', 
                                 cv=skf).fit(X_train, y_train)
    
    # Получение предсказаний
    y_prob = current_model.predict_proba(X_test)[:, 1]
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_prob)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results_4.loc[model_name] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{model_name}:\033[0m\nTraining time: " +
          f"{round(stop - start, 2)}s\nBest Params: {current_model.best_params_}\n")

# Обучение моделей, у которых нет метода "predict_proba", на кросс-валидации с подбором гиперпараметров
for model_name, mp in without_predict_proba_params.items():
    start = time.time()
    current_model = GridSearchCV(mp['model'], 
                                 param_grid=mp['params'], 
                                 scoring='roc_auc', 
                                 cv=skf).fit(X_train, y_train)
    
    # Получение предсказаний
    y_dec = current_model.decision_function(X_test)
    y_pred = current_model.predict(X_test)
    
    # Получение результатов метрик
    roc_auc = roc_auc_score(y_test, y_dec)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results_4.loc[model_name] = [roc_auc, precision, recall, f1]
    stop = time.time()
    print(f"\033[1m{model_name}:\033[0m\nTraining time: " +
          f"{round(stop - start, 2)}s\nBest Params: {current_model.best_params_}\n")
    
results_4.sort_values('roc_auc_score', ascending=False)
# Out:
# LogisticRegression:
# Training time: 15.18s
# Best Params: {'C': 10, 'max_iter': 100, 'solver': 'lbfgs'}
#
# GradientBoostingClassifier:
# Training time: 41.86s
# Best Params: {'learning_rate': 0.1}
#
# AdaBoostClassifier:
# Training time: 182.2s
# Best Params: {'learning_rate': 0.5000000000000001, 'n_estimators': 25}
#
# LinearSVC:
# Training time: 7.63s
# Best Params: {'C': 0.9000000000000001, 'fit_intercept': True, 'tol': 0.0001}
#
# SGDClassifier:
# Training time: 156.26s
# Best Params: {'alpha': 0.0007000000000000001, 'eta0': 0.0}
#                            roc_auc_score precision_score recall_score  \
# AdaBoostClassifier              0.836688        0.638961     0.531317
# GradientBoostingClassifier      0.835355         0.63172     0.507559
# LogisticRegression              0.828743        0.617647      0.49892
# LinearSVC                       0.824058        0.617486     0.488121
# SGDClassifier                   0.822312        0.587852     0.585313
# ...

# %%
# Проверка, насколько изменились значения метрик
results_4 - results_3.loc[['AdaBoostClassifier', 'GradientBoostingClassifier', 
                           'LogisticRegression', 'LinearSVC', 'SGDClassifier', 'GaussianNB'], :]
# Out:
#                            roc_auc_score precision_score recall_score  \
# AdaBoostClassifier              0.003823        0.007241     0.023758
# GaussianNB                           0.0             0.0          0.0
# GradientBoostingClassifier           0.0             0.0          0.0
# LinearSVC                            0.0             0.0          0.0
# LogisticRegression              0.000198        0.002262     -0.00216
# SGDClassifier                   0.006264         -0.0026     0.077754
#
#                             f1_score
# AdaBoostClassifier          0.017314
# GaussianNB                       0.0
# GradientBoostingClassifier       0.0
# LinearSVC                        0.0
# LogisticRegression          -0.00041
# SGDClassifier               0.040703

# %% [markdown]
# Метрики практически не изменились.

# %% [markdown]
# # 4. Сравнение качества моделей

# %%
results_4.sort_values('roc_auc_score', ascending=False)
# Out:
#                            roc_auc_score precision_score recall_score  \
# AdaBoostClassifier              0.836688        0.638961     0.531317
# GradientBoostingClassifier      0.835355         0.63172     0.507559
# LogisticRegression              0.828743        0.617647      0.49892
# LinearSVC                       0.824058        0.617486     0.488121
# SGDClassifier                   0.822312        0.587852     0.585313
# GaussianNB                      0.806288        0.505155     0.740821
#
#                             f1_score
# AdaBoostClassifier          0.580189
# GradientBoostingClassifier  0.562874
# LogisticRegression          0.551971
# LinearSVC                   0.545235
# SGDClassifier                0.58658
# GaussianNB                  0.600701

# %%
# Создание подходящей цветовой палитры
boundaries = [value for value in matrixes['GaussianNB'].flatten().tolist()]
list.sort(boundaries)
colors = ["#e17d7a","#db635e","#d44842","#a93947","#7e2a4b","#531b4f","#3e1351","#280b53"]
norm = matplotlib.colors.BoundaryNorm(boundaries=boundaries + [boundaries[-1]], ncolors=256)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

# Визуализация confusion_matrix топовых алгоритмов
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
fig.suptitle('Confusion matrixes of top classifiers', fontsize=22)

for key, ax in zip(matrixes.keys(), axes.ravel()):
    sns.heatmap(matrixes[key], 
                       annot=True, fmt='3.0f',
                       vmin=0, vmax=1200, 
                       cmap=cmap,
                       ax=ax)
    
    # Включение рамок
    for _, spine in ax.spines.items():
        spine.set_visible(True)
        spine.set_linewidth(0.3)
        
    ax.set_title(key, fontsize=18)
    ax.set_ylabel('Predicted', fontsize=16)
    ax.set_xlabel('Actual', fontsize=16)
    
plt.tight_layout(pad=1.03)
plt.show()

# %%
# Визуализация всех метрик одновременно для топовых алгоритмов
results_4.plot(kind='bar', figsize=(15, 6))

plt.title('Values of various metrics for top classifiers', fontsize=18)
plt.xticks(rotation=0)
plt.legend(title='Metrics', bbox_to_anchor=(1, 0.6))

plt.box(None)
plt.show()

# %%
# Визуализация точности и полноты топовых алгоритмов для более детального рассмотрения
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

fig.suptitle('Values of precision & recall for top classifiers', fontsize=18, y=1)

for metric, ax in zip(['recall_score', 'precision_score'], axes.ravel()):
    sns.barplot(y=results_4.index, x=results_4.loc[:, metric], ax=ax)
    
    # Отключение рамок
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
        
    # Отображение значения метрики на графики
    for i in ax.patches:
        ax.text(x=i.get_width() - 0.07,
                y=i.get_y() + 0.5, 
                s=str(round(i.get_width(), 3)),
                c='white',
                fontsize=11)

axes[0].set_xlabel('Recall', fontsize=14)
axes[1].set_xlabel('Precision', fontsize=14)

plt.tight_layout(pad=1.03)
plt.show()

# %%
# Объединение результатов всех вариантов обучения
all_results = pd.concat([results.set_index(results.index + ' Default'),
                         results_2.set_index(results_2.index + ' PCA'),
                         results_3.set_index(results_3.index + ' Important_features'),
                         results_4.drop('GaussianNB').set_index(
                             results_4.drop('GaussianNB').index + ' Important_features Tunned')])

# %%
# Сравнение всех моделей по метрике roc_auc_score
all_results.sort_values('roc_auc_score', ascending=False)
# Out:
#                                                    roc_auc_score  \
# GradientBoostingClassifier Default                       0.83688
# AdaBoostClassifier Important_features Tunned            0.836688
# AdaBoostClassifier Default                              0.836398
# GradientBoostingClassifier Important_features T...      0.835355
# GradientBoostingClassifier Important_features           0.835355
# LogisticRegression PCA                                  0.833467
# LogisticRegression Default                              0.833464
# AdaBoostClassifier Important_features                   0.832865
# GradientBoostingClassifier PCA                          0.830447
# LinearSVC Default                                        0.82894
# LinearSVC PCA                                           0.828927
# LogisticRegression Important_features Tunned            0.828743
# LogisticRegression Important_features                   0.828546
# ...

# %%
# Выделение лучших моделей по метрике recall_score
all_results.sort_values('recall_score', ascending=False).head()
# Out:
#                                              roc_auc_score precision_score  \
# GaussianNB Important_features                     0.806288        0.505155
# GaussianNB Default                                0.812695        0.508423
# SGDClassifier Important_features Tunned           0.822312        0.587852
# GaussianNB PCA                                    0.803865        0.581776
# AdaBoostClassifier Important_features Tunned      0.836688        0.638961
#
#                                              recall_score  f1_score
# GaussianNB Important_features                    0.740821  0.600701
# GaussianNB Default                               0.717063  0.594982
# SGDClassifier Important_features Tunned          0.585313   0.58658
# GaussianNB PCA                                   0.537797  0.558923
# AdaBoostClassifier Important_features Tunned     0.531317  0.580189

# %% [markdown]
# * Можно сказать, что *auc_roc_score* большинства моделей одинаковый.
# * **DecisionTreeClassifier** и **KNeighborsClassifier** точно не стоит использовать.
# * По метрике *recall_score* наилучшей моделью является алгоритм **GaussianNB**, обученный на отобранных признаках. Для нашей задачи при равных *auc_roc_score* значение *recall* важнее, чем значение *precision*. Значение *auc_roc_score* у данной модели относительно неплохое. Возможно, именно ее и стоит использовать.
#
# Для более точного решения необходима так же оценка по другим параметрам: время обучения моделей, а также соответствие бизнес-задачи.
